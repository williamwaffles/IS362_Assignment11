# %% [markdown]
# # IS 362 - Assignment 11

# %% [markdown]
# ## The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs You’ll need to start by signing up for an API key.
#
# ## Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %%
import requests as re
import pandas as pd

# Using the Books API from NY Times: https://developer.nytimes.com/docs/books-product/1/overview

# %% [markdown]
# #### Set base API URL and API Keys

# %%
base_url = 'https://api.nytimes.com/svc/books/v3/lists.json'
api_key = 'TPrMxI5GlpSDfhaAgsiEWOnB9mXwlUP7'
api_sk = 'Qb6wxL3blFFOxeIc'

# %% [markdown]
# #### Set URL header for query parameters

# %%
params = {
        'list' : 'hardcover-nonfiction',
        'api-key': 'TPrMxI5GlpSDfhaAgsiEWOnB9mXwlUP7'
    }

# %% [markdown]
# #### Retrieve API request as .json

# %%
response = re.get(base_url, params=params)
response.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2022 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2022-11-02T22:14:55-04:00',
#  'results': [{'list_name': 'Hardcover Nonfiction',
#    'display_name': 'Hardcover Nonfiction',
#    'bestsellers_date': '2022-10-29',
#    'published_date': '2022-11-13',
#    'rank': 1,
#    'rank_last_week': 0,
#    'weeks_on_list': 1,
#    'asterisk': 0,
#    'dagger': 1,
#    'amazon_product_url': 'https://www.amazon.com/dp/1668001845?tag=NYTBSREV-20',
#    'isbns': [{'isbn10': '1668001845', 'isbn13': '9781668001844'},
#     {'isbn10': '1668001861', 'isbn13': '9781668001868'}],
#    'book_details': [{'title': "RADIO'S GREATEST OF ALL TIME",
#      'description': 'A collection of the late conservative commentator’s on-air moments, with memories from his widow and brother.',
#      'contributor': 'by Rush Limbaugh with Kathryn Adams Limbaugh and David Limbaugh',
# ...

# %% [markdown]
# #### Convert .json output to a DataFrame!

# %%
output = response.json()
df = pd.DataFrame.from_dict(output)
df
# Out:
#    status                                          copyright  num_results  \
# 0      OK  Copyright (c) 2022 The New York Times Company....           15
# 1      OK  Copyright (c) 2022 The New York Times Company....           15
# 2      OK  Copyright (c) 2022 The New York Times Company....           15
# 3      OK  Copyright (c) 2022 The New York Times Company....           15
# 4      OK  Copyright (c) 2022 The New York Times Company....           15
# 5      OK  Copyright (c) 2022 The New York Times Company....           15
# 6      OK  Copyright (c) 2022 The New York Times Company....           15
# 7      OK  Copyright (c) 2022 The New York Times Company....           15
# 8      OK  Copyright (c) 2022 The New York Times Company....           15
# 9      OK  Copyright (c) 2022 The New York Times Company....           15
# 10     OK  Copyright (c) 2022 The New York Times Company....           15
# 11     OK  Copyright (c) 2022 The New York Times Company....           15
# ...
